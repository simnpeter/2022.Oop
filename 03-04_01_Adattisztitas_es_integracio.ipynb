# %% [markdown]
# # Adattisztítás és integráció

# %% [markdown]
# A valós adathalmazok gyakran zajosak, hiányosak, avagy éppen redundáns információt vagy duplikátum egyedeket tartalmaznak. Ezért a tudásfeltárás folyamatában az adattisztítás és adatintegrálással kezdődik.
#
# Az adattisztítás szerepe javítani az adatok minőségén azáltal, hogy kiszűri és eltávolítja az adatokban fellépő hibákat és inkonzisztenciákat.
#
# Az [adattisztítás](https://hu.wikipedia.org/wiki/Adattiszt%C3%ADtás) során:
# - felmérjük a hibákat
# 	- ellenőrizzük az adatfájl szerkezeti épségét
# 	- a zajt, felesleges információt tartalmazó mezőket javítjuk
# 	- felmérjük a hiányzó értékeket és amennyiben lehet ezeket pótoljuk
# 	- felmérjük az adatközlési és adatbeviteli hibákat
# 		- megvizsgáljuk az egyes változók eloszlását
# 			- az eloszlások szélein elhelyezkedő extrém értékeket ellenőrizzük
# 			- felmérjük, hogy az eloszlások megfelelnek-e az előzetes elvárásainknak, vannak-e nem várt sűrűsödések, ritkulások egyes értéktartományokban (például durva kerekítés vagy eltérő mértékegység használata az adatszolgáltatók egy részénél)
# 		-  megvizsgáljuk, hogy a változók közötti triviális összefüggések teljesülnek-e
# -  a hibásnak tűnő adatokat felülvizsgáljuk, javítjuk.

# %% [markdown]
# # Feladatok

# %% [markdown]
# Az adatok letöltésére használjuk a `requests` könyvtárat. A requests könyvtár lehetővé teszi, hogy az internetről HTTPS protokollal bármilyen állományt letöltsünk, beleértve HTML dokumentumokat is. Sokszor megtörténhet, hogy az adatokat egy weboldalról kell letöltenünk, majd tisztítanunk valamely módon.
#
# A HTML-es adatok feldolgozására használjuk a `BeautifulSoup4` könyvtárat. A `BeautifulSoup4` könyvtár segítségével fel tudjuk dolgozni a HTML adatokat. A könyvtár lehetővé teszi, hogy betöltsük a memóriába a HTML-ből vett struktúrákat, és általánosan tudjunk benne keresni elemeket, kiolvasni attribútumokat, stb.

# %% [markdown]
# 1. A requests, BeautifulSoup4, plotly és nbformat könyvtárak nem képezik részét a Python standard könyvtárkészletének. Töltsük le a pip package managerrel ezeket a könyvtárakat.

# %%
#!python -m pip install requests beautifulsoup4 plotly nbformat --upgrade --user

# %% [markdown]
# ## Amerikai egyetemek

# %% [markdown]
# 1. Az `egyetemek.txt` fájlból szűrjük ki az államokat és azon belül a városokat, melyben egyetemek találhatóak. Ha vannak duplikátumok, helytelen adatok (pl. számokat tartalmazó államnév), ezeket javítsuk. Vizsgáljuk meg az egyetemek eloszlását államok szerint.

# %%
from collections import namedtuple
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')

path='/content/drive/My Drive/Colab Notebooks/egyetemek.txt'

Item = namedtuple('Item', 'state city university')
items = []
i=0
nums = '0123456789'

def hasNum(text):
  for ch in text:
    if ch in nums:
      return True
    return False

with open(path,'r') as f:
    for line in f:
        clear_line = line.rstrip('\n')
        if clear_line.endswith('[edit]'):
          if hasNum(clear_line):
            continue
          state = clear_line.rstrip('[edit]')
        else:

          start_index = clear_line.find('(')
          end_index = clear_line.find(')')

          city = clear_line[:start_index-2]
          if hasNum(city):
            continue

          universities = clear_line[start_index:]
          universities = universities[1:end_index]
          universities = universities.split(")")
          universities = universities[0]
          cutted_universities = universities.split(", ")
          for uni in cutted_universities:
            if hasNum(uni):
              continue
            items.append(Item(state, city, uni))


          i = i+1

df = pd.DataFrame.from_records(items, columns=['State', 'City', 'Universities'])

#print(df[df.State == "Alabama"])
print(df)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#          State          City                           Universities
# 0      Alabama         Aubur                      Auburn University
# 1      Alabama       Florenc            University of North Alabama
# 2      Alabama   Jacksonvill          Jacksonville State University
# 3      Alabama     Livingsto             University of West Alabama
# 4      Alabama     Montevall               University of Montevallo
# ..         ...           ...                                    ...
# 728  Wisconsin    River Fall    University of Wisconsin–River Falls
# 729  Wisconsin  Stevens Poin  University of Wisconsin–Stevens Point
# 730  Wisconsin       Waukesh                     Carroll University
# 731  Wisconsin     Whitewate     University of Wisconsin–Whitewater
# 732    Wyoming        Larami                  University of Wyoming
#
# [733 rows x 3 columns]

# %% [markdown]
# 2. Melyik államban van a legtöbb, legkevesebb egyetem?

# %%
def most_uni(df):
  return df.groupby(df.State)['Universities'].count().idxmax()

def leas_uni(df):
  return df.groupby(df.State)['Universities'].count().idxmin()

# %%
most = most_uni(df)
print(most)

least = leas_uni(df)
print(least)
# Out:
# New York
# Alaska

# %% [markdown]
# 3. Bővítsük ki az adatbázisunkat egy oszloppal, mely tartalmazza az államok rövidítését is (pl. Texas - TX, California - CA stb.).  [Forrás](https://en.wikipedia.org/wiki/List_of_U.S._state_abbreviations).

# %%
# Importáljuk a könyvtárakat
import pandas as pd
import requests
import bs4

# Álcázzuk magunkat egy webböngészőnek
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36'
headers = {'User-Agent': user_agent}

url = 'https://en.wikipedia.org/wiki/List_of_U.S._state_and_territory_abbreviations'

# Töltsük le a weboldalt
with requests.get(url, headers=headers) as req:
    # Ha nem sikerült a letöltés, akkor hibát dobunk
    req.raise_for_status()

    # A letöltött HTML-t lementjük egy változóba
    html_data = req.text

# %%
# A BeautifulSoup segítségével dolgozzuk fel a letöltött HTML-t
soup = bs4.BeautifulSoup(html_data, features='html.parser')

# Keresük meg az oldalon azt a táblázatot, aminek az osztálya 'wikitable sortable'
table = soup.find('table', {'class': 'wikitable sortable'})

# A táblázatban keressük meg a sorokat
table_rows = table.find_all('tr')

# Ide fogjuk menteni az államok nevét és rövidítését
states = []
abbreviations = []

for table_row in table_rows:
    # A sorokon belül keressük meg az oszlopokat
    table_cols = table_row.find_all('td')

    # Ha az oszlopok száma 10, akkor egy államról van szó
    if len(table_cols) == 10:
        # Az állam neve a 0. oszlopban található
        state = table_cols[0].text

        # Az állam rövidítése a 3. oszlopban található
        abbreviation = table_cols[3].text

        if not abbreviation:
            # Ha nincs rövidítése az államnak, akkor a következő sorra ugrunk
            continue

        states.append(state)
        abbreviations.append(abbreviation)

# Hozzuk létre a DataFrame-et
state_abbreviations = pd.DataFrame({'State': states, 'Abbreviation': abbreviations})
state_abbreviations
# Out:
#                         State Abbreviation
# 0    United States of America           US
# 1                     Alabama           AL
# 2                      Alaska           AK
# 3                     Arizona           AZ
# 4                    Arkansas           AR
# 5                  California           CA
# 6                    Colorado           CO
# 7                 Connecticut           CT
# 8                    Delaware           DE
# 9        District of Columbia           DC
# 10                    Florida           FL
# 11                    Georgia           GA
# 12                     Hawaii           HI
# 13                      Idaho           ID
# 14                   Illinois           IL
# 15                    Indiana           IN
# 16                       Iowa           IA
# 17                     Kansas           KS
# 18                   Kentucky           KY
# 19                  Louisiana           LA
# 20                      Maine           ME
# 21                   Maryland           MD
# 22              Massachusetts           MA
# 23                   Michigan           MI
# 24                  Minnesota           MN
# 25                Mississippi           MS
# 26                   Missouri           MO
# 27                    Montana           MT
# 28                   Nebraska           NE
# 29                     Nevada           NV
# 30              New Hampshire           NH
# 31                 New Jersey           NJ
# 32                 New Mexico           NM
# 33                   New York           NY
# 34             North Carolina           NC
# 35               North Dakota           ND
# 36                       Ohio           OH
# 37                   Oklahoma           OK
# 38                     Oregon           OR
# 39               Pennsylvania           PA
# 40               Rhode Island           RI
# 41             South Carolina           SC
# 42               South Dakota           SD
# 43                  Tennessee           TN
# 44                      Texas           TX
# 45                       Utah           UT
# 46                    Vermont           VT
# 47                   Virginia           VA
# 48                 Washington           WA
# 49              West Virginia           WV
# 50                  Wisconsin           WI
# 51                    Wyoming           WY
# 52             American Samoa           AS
# 53                       Guam           GU
# 54   Northern Mariana Islands           MP
# 55                Puerto Rico           PR
# 56        U.S. Virgin Islands           VI
# 57           Marshall Islands           MH
# 58                 Micronesia           FM
# 59                      Palau           PW

# %%
# Rövidítések hozzáadása
import pandas as pd

df['State'] = df['State'].str.strip()
state_abbreviations['State'] = state_abbreviations['State'].str.strip()

df = pd.merge(df, state_abbreviations, on='State')


print(df[['Abbreviation', 'State', 'City', 'Universities']])
# Out:
#     Abbreviation      State          City  \
# 0             AL    Alabama         Aubur
# 1             AL    Alabama       Florenc
# 2             AL    Alabama   Jacksonvill
# 3             AL    Alabama     Livingsto
# 4             AL    Alabama     Montevall
# ..           ...        ...           ...
# 626           WI  Wisconsin    River Fall
# 627           WI  Wisconsin  Stevens Poin
# 628           WI  Wisconsin       Waukesh
# 629           WI  Wisconsin     Whitewate
# 630           WY    Wyoming        Larami
#
#                               Universities
# 0                        Auburn University
# 1              University of North Alabama
# 2            Jacksonville State University
# 3               University of West Alabama
# 4                 University of Montevallo
# ..                                     ...
# 626    University of Wisconsin–River Falls
# 627  University of Wisconsin–Stevens Point
# 628                     Carroll University
# 629     University of Wisconsin–Whitewater
# 630                  University of Wyoming
#
# [631 rows x 4 columns]

# %% [markdown]
# 4. Hasonlóan, a [List of U.S. states and territories by area](https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_area) linken szereplő területi adatokat is integráljuk be a datasetünkbe.

# %%
import pandas as pd
import requests
import bs4

# Álcázzuk magunkat egy webböngészőnek
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36'
headers = {'User-Agent': user_agent}

url = 'https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_area'

# Töltsük le a weboldalt
with requests.get(url, headers=headers) as req:
    # Ha nem sikerült a letöltés, akkor hibát dobunk
    req.raise_for_status()

    # A letöltött HTML-t lementjük egy változóba
    html_data = req.text

# %%
# A BeautifulSoup segítségével dolgozzuk fel a letöltött HTML-t
soup = bs4.BeautifulSoup(html_data, features='html.parser')
# Keresük meg az oldalon azt a táblázatot, aminek az osztálya 'wikitable sortable'
table = soup.find('table', {'class': 'wikitable sortable sticky-header-multi static-row-numbers col1left'})


# A táblázatban keressük meg a sorokat
table_rows = table.find_all('tr')

# Ide fogjuk menteni az államok nevét és rövidítését
states = []
total_area = []
land_area = []
water_area = []



for table_row in table_rows:
    # A sorokon belül keressük meg az oszlopokat
    table_cols = table_row.find_all('td')

    # Ha az oszlopok száma 9, akkor egy államról van szó
    if len(table_cols) == 8:
        # Az állam neve a 1. oszlopban található
        state = table_cols[0].text
        if 'Contiguous US' in state:
          break
        # a total area km^2 3. oszlop
        total = table_cols[2].text
        # a land area km^2 5. oszlop
        land = table_cols[4].text
        # a water area km^2 7. oszlop
        water = table_cols[6].text

        states.append(state)
        total_area.append(pd.to_numeric(total.replace(',', '')))
        land_area.append(pd.to_numeric(land.replace(',', '')))
        water_area.append(pd.to_numeric(water.replace(',', '')))

# Hozzuk létre a DataFrame-et
state_area = pd.DataFrame({'State': states, 'Total': total_area, 'Land': land_area, 'Water': water_area})
state_area
# Out:
#                             State    Total     Land   Water
# 0                          Alaska  1723337  1477953  245383
# 1                           Texas   695662   676587   19075
# 2                      California   423967   403466   20501
# 3                         Montana   380831   376962    3869
# 4                      New Mexico   314917   314161     757
# 5                         Arizona   295234   294207    1026
# 6                          Nevada   286380   284332    2048
# 7                        Colorado   269601   268431    1170
# 8                          Oregon   254799   248608    6191
# 9                         Wyoming   253335   251470    1864
# 10                       Michigan   250487   146435  104052
# 11                      Minnesota   225163   206232   18930
# 12                           Utah   219882   212818    7064
# 13                          Idaho   216443   214045    2398
# 14                         Kansas   213100   211754    1346
# 15                       Nebraska   200330   198974    1356
# 16                   South Dakota   199729   196350    3379
# 17                     Washington   184661   172119   12542
# 18                   North Dakota   183108   178711    4397
# 19                       Oklahoma   181037   177660    3377
# 20                       Missouri   180540   178040    2501
# 21                        Florida   170312   138887   31424
# 22                      Wisconsin   169635   140268   29367
# 23                        Georgia   153910   148959    4951
# 24                       Illinois   149995   143793    6202
# 25                           Iowa   145746   144669    1077
# 26                       New York   141297   122057   19240
# 27                 North Carolina   139391   125920   13471
# 28                       Arkansas   137732   134771    2961
# 29                        Alabama   135767   131171    4597
# 30                      Louisiana   135659   111898   23761
# 31                    Mississippi   125438   121531    3907
# 32                   Pennsylvania   119280   115883    3397
# 33                           Ohio   116098   105829   10269
# 34                       Virginia   110787   102279    8508
# 35                      Tennessee   109153   106798    2355
# 36                       Kentucky   104656   102269    2387
# 37                        Indiana    94326    92789    1537
# 38                          Maine    91633    79883   11750
# 39                 South Carolina    82933    77857    5076
# 40                  West Virginia    62756    62259     497
# 41                       Maryland    32131    25142    6990
# 42                         Hawaii    28313    16635   11678
# 43                  Massachusetts    27336    20202    7134
# 44                        Vermont    24906    23871    1035
# 45                  New Hampshire    24214    23187    1027
# 46                     New Jersey    22591    19047    3544
# 47                    Connecticut    14357    12542    1816
# 48                    Puerto Rico    13791     8868    4924
# 49                       Delaware     6446     5047    1399
# 50       Northern Mariana Islands     5117      472    4644
# 51                   Rhode Island     4001     2678    1324
# 52            U.S. Virgin Islands     1898      348    1550
# 53                 American Samoa     1505      198    1307
# 54                           Guam     1478      543     935
# 55           District of Columbia      177      158      19
# 56   Minor Outlying Islands[3][a]       41       41       0

# %%
# Területek hozzáadása
import pandas as pd

state_area['State'] = state_area['State'].str.strip()

df = pd.merge(df, state_area, on='State')


print(df)

# %%
df.head()
# Out:
#      State         City                   Universities Abbreviation   Total  \
# 0  Alabama        Aubur              Auburn University           AL  135767
# 1  Alabama      Florenc    University of North Alabama           AL  135767
# 2  Alabama  Jacksonvill  Jacksonville State University           AL  135767
# 3  Alabama    Livingsto     University of West Alabama           AL  135767
# 4  Alabama    Montevall       University of Montevallo           AL  135767
#
#      Land  Water
# 0  131171   4597
# 1  131171   4597
# 2  131171   4597
# 3  131171   4597
# 4  131171   4597

# %% [markdown]
# 5. Számoljuk ki államonként átlagban hány négyzetkilométerre jut egy egyetemi város.

# %%
import pandas as pd

def avg_uni_area(df):
  grouped = df.groupby('State')
  size = grouped.size()

  average_area_per_city = grouped['Total'].mean() / size
  return average_area_per_city.astype(int)

print(avg_uni_area(df))
# Out:
# State
# Alabama             13576
# Alaska            1723337
# Arizona             98411
# Arkansas            12521
# California           7570
# Colorado            29955
# Florida              9461
# Georgia              7329
# Idaho               72147
# Illinois            14999
# Indiana              6737
# Iowa                11211
# Kansas              26637
# Kentucky             8050
# Louisiana           15073
# Massachusetts         650
# Michigan            10890
# Minnesota            9381
# Montana            126943
# Nebraska            28618
# Nevada              71595
# New Jersey           2259
# New Mexico          62983
# New York             2207
# North Carolina       5361
# North Dakota        91554
# Ohio                 5047
# Oklahoma            15086
# Oregon              19599
# Pennsylvania         2168
# South Carolina       3949
# South Dakota        49932
# Texas               21739
# Utah                36647
# Virginia             4431
# Washington          36932
# West Virginia        6972
# Wisconsin           10602
# Wyoming            253335
# dtype: int64

# %% [markdown]
# 6. Az ábrán a kivitel (exportmennyiség) van ábrázolva az Amerikai Egyesült Államok térképen, államonként lebontva. Készítsünk hasonló ábrákat az egyetemek eloszlásáról is. A [térképen való ábrázolás](https://plotly.com/python/maps/) Plotly segítségével történhet.

# %%
import plotly.graph_objects as go
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_us_ag_exports.csv')

fig = go.Figure(data=go.Choropleth(
	locations=df['code'], # államok kódja,
	z = df['total exports'].astype(float), # adat, amit színezni akarunk
	locationmode = 'USA-states',
	colorscale = 'Reds',
	colorbar_title = 'Millions USD'
))
fig.update_layout(
	title_text = '2011 US Agriculture Exports by State',
	geo_scope='usa' # csak az USA-t jelenítsük meg
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="98fedc28-b653-4076-b4d1-fb40e4b1ccfc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98fedc28-b653-4076-b4d1-fb40e4b1ccfc")) {                    Plotly.newPlot(                        "98fedc28-b653-4076-b4d1-fb40e4b1ccfc",                        [{"colorbar":{"title":{"text":"Millions USD"}},"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"locationmode":"USA-states","locations":["AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"z":[1390.63,13.31,1463.17,3586.02,16472.88,1851.33,259.62,282.19,3764.09,2860.84,401.84,2078.89,8709.48,5050.23,11273.76,4589.01,1889.15,1914.23,278.37,692.75,248.65,3164.16,7192.33,2170.8,3933.42,1718.0,7114.13,139.89,73.06,500.4,751.58,1488.9,3806.05,3761.96,3979.79,1646.41,1794.57,1969.87,31.59,929.93,3770.19,1535.13,6648.22,453.39,180.14,1146.48,3894.81,138.89,3090.23,349.69],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d": ...

# %% [markdown]
# ## Vásárhelyi éttermek

# %% [markdown]
# Keressük meg Vásárhelyen a legolcsóbb és legdrágább pizzákat. A pizzákat keressük meg az [eeatingh.ro](https://eeatingh.ro) oldalán. Az [eeatingh.ro](https://eeatingh.ro) oldalon több étterem található, mindegyik étterem közzé teszi a saját menüjét.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Használjuk a requests könyvtárat, hogy letöltsük az éttermek listáját a főoldalról. Mentsük le az éttermek nevét (például: Rexo LunchBox), illetve az étteremhez tartozó adatlap elérhetőségét (például: `https://eeatingh.ro/targu-mures/rexo-lunchbox.html`) egy DataFramebe. Mentsük ki a DataFrame-et egy állományba, hogy később gyorsabban lehessen az adatokat feldolgozni!
#
# Segítség: Használjuk a Chrome-ban a beépített `Inspect Element` funkcionalitást. Keressük meg a HTML dokumentumban, hogy hol vannak lementve az éttermek. Minden éttermet külön entitásnak tekinthetünk. Kerssük meg, hogy egy éttermen belül hol van lementve az étterem neve, illetve az étteremhez tartozó adatlap elérhetősége. Ezeket az információkat használjuk fel arra, hogy megírjuk a HTML feldolgozását a BeautifulSoup4 segítségével.

# %%
#eeathing éttermek

# Importáljuk a könyvtárakat
from collections import namedtuple
import pandas as pd
import requests
import bs4
import csv
import re
from google.colab import drive

drive.mount('/content/drive')

# Álcázzuk magunkat egy webböngészőnek
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36'
headers = {'User-Agent': user_agent}

url_food = 'https://eeatingh.ro/targu-mures.html'

with requests.get(url_food, headers=headers) as req:
    # Ha nem sikerült a letöltés, akkor hibát dobunk
    req.raise_for_status()

    # A letöltött HTML-t lementjük egy változóba
    html_food_data = req.text

# A BeautifulSoup segítségével dolgozzuk fel a letöltött HTML-t
soup_food = bs4.BeautifulSoup(html_food_data, features='html.parser')

all_restaurants = soup_food.find('div', {'class': 'listStoresBox'})

rest_names = []
rest_links = []

if all_restaurants:
    # print("van")
    # Az összes étterem nevének kinyerése
    allRestaurants_divs = all_restaurants.find_all('a', class_= 'storeItem')
    # print(allRestaurants_divs)
    for div in allRestaurants_divs:
        span = div.find('span', {'class': 'name semibold'})
        link = div.get('href')
        if span:
            rest_names.append(span.text.strip())
            rest_links.append(link)
            # print(span.text.strip())
            # print(link)

# print(rest_names)
# print(rest_links)

foodItem = namedtuple('Item', 'restaurant_name url food_name description price')
foodItems = []
i = 0

for link,name in zip(rest_links, rest_names):
    print(link)
    print(name)
    try:
      with requests.get(link, headers=headers) as req:
        # Ha nem sikerült a letöltés, akkor hibát dobunk
        req.raise_for_status()

        # A letöltött HTML-t lementjük egy változóba
        html_one_food_data = req.text

      soup_one_food = bs4.BeautifulSoup(html_one_food_data, features='html.parser')

      # content = soup_one_food.find('div', {'class': 'content'})
      # store_box = content.find('div', {'class': 'storeBox'})
      # storeWrapper_template1 = store_box.find('div',{'class': 'storeWrapper template1'})
      content = soup_one_food.find('div', {'class': 'storeContent'})
      storeContent = content.find_all('div', {'class': 'productWrap'})
      # print(storeContent)
      for food in storeContent:
        foodNameDiv = food.find('div', {'class': 'productInfoWrap'})
        foodName = foodNameDiv.find('h1', {'class': 'productTitle semibold'})
        foodName = foodName.text
        foodDescription = foodNameDiv.find('div', {'class': 'productDescription'})

        foodMoreDescription = foodNameDiv.find('a', {'class': 'moreDetails'})
        if foodMoreDescription:
          foodDescription = foodMoreDescription.get('title')
        else:
          foodDescription = foodDescription.text

        productSizesWrap = foodNameDiv.find('div', {'class': 'productSizesWrap'})
        prices = productSizesWrap.find_all('a')
        for price in prices:
          small_desc = price.find('span', {'class': 'descriptionInfo'})
          if small_desc:
            newFoodName = foodName + small_desc.text
          else:
            newFoodName = foodName
          foodPrice = price.find('span', {'class': 'amount bold'})
          foodPrice = foodPrice.text
          foodPrice = re.findall(r'\d+', foodPrice)
          foodPrice = ''.join(foodPrice)
          price_as_int = int(foodPrice)
          foodItems.append(foodItem(name,link,newFoodName, foodDescription, foodPrice))
        print('-------------------------------------------------------------------------------------------')
        print(newFoodName, '    ', foodPrice)
        print(foodDescription)
    except requests.exceptions.HTTPError as err:
      if req.status_code == 404:
        continue

print(foodItems)


new_path = '/content/drive/My Drive/Colab Notebooks/foodInfo.csv'
with open(new_path, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['restaurant_name', 'url', 'food_name', 'description', 'price']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()

    for food_info in foodItems:
        writer.writerow({
            'restaurant_name': food_info.restaurant_name,
            'url': food_info.url,
            'food_name': food_info.food_name,
            'description': food_info.description,
            'price': food_info.price
        })
# Out:
# Streaming output truncated to the last 5000 lines.
# -------------------------------------------------------------------------------------------
# White Mocca Classico 250ml      10
# Espresso 30 ml, cremă de lapte 200 ml, sirop de ciocolată albă 20 ml
# -------------------------------------------------------------------------------------------
# White Mocca Medium 350ml      12
# espresso 30 ml, crema de lapte 300 ml, sirop ciocolata alba 20 ml
# -------------------------------------------------------------------------------------------
# Vanilla Cinnamon Latte 250 ml      10
# Espresso 30 ml, cremă de lapte 200 ml, sirop de vanilie si  scorțișoara 20 ml
# -------------------------------------------------------------------------------------------
# Toffe Crunch choco 250 ml      11
# Ciocolată caldă clasică 30 g , lapte 200 , sirop de toffee crunch 20 ml
# -------------------------------------------------------------------------------------------
# White Mocca Grande 400ml      14
# Espresso 30 ml, cremă de lapte 350 ml, sirop de ciocolată albă 20 ml
# -------------------------------------------------------------------------------------------
# Salted Caramel  Latte  350 ml      12
# Espresso 30 ml, cremă de lapte 300 ml, sirop de caramel sărat 20 ml
# -------------------------------------------------------------------------------------------
# Pistacchio Latte Classico 250 ml      10
# Espresso 30 ml, cremă de lapte 200 ml, sirop de fistic 20 ml
# -------------------------------------------------------------------------------------------
# Tiramisu Capuccino Classico 250 ml      10
# Espresso 30 ml, cremă de lapte 200 ml, sirop de tiramisu 20 ml
# -------------------------------------------------------------------------------------------
# Salted Caramel Classico 250ml- choco      9
# Ciocolată caldă albă, lapte, sirop de camel sărat, frișcă
# -------------------------------------------------------------------------------------------
# Salted Caramel Medium 350ml - Choco      10
# Ciocolată caldă albă, lapte, sirop de camel sărat, frișcă
# -------------------------------------------------------------------------------------------
# Macadamia Medium 350ml - choco      11
# Ciocolată caldă clasică, lapte, sirop de macadamia, frișcă
# -------------------------------------------------------------------------------------------
# Pistacchio Classico 250ml - choco      11
# Ciocolată caldă clasică 30 g, lapte 200 ml, sirop de fistic 20 ml
# -------------------------------------------------------------------------------------------
# Toffee Crunch Classico 250ml - choco      9
# Ciocolată caldă clasică, lapte, sirop de toffee crunch, frișcă
# -------------------------------------------------------------------------------------------
# Toffee Crunch Medium 350ml- choco      11
# Ciocolată caldă clasică, lapte, sirop de toffee crunch, frișcă
# -------------------------------------------------------------------------------------------
# Nana Mint Herbal Medium 350 ml      8
#
# -------------------------------------------------------------------------------------------
# Earl Grey Black Medium 350 ml      8
#
# -------------------------------------------------------------------------------------------
# Rooisbos Orange Medium 350 ml      8
#
# -------------------------------------------------------------------------------------------
# Forestberry Cocktail Medium 350 ml      8
# Ceai de fructe de pădure, miere, suc de lămâie, gheață
# -------------------------------------------------------------------------------------------
# Yogurt Berry Medium 400 ml      14
# Fructe de pădure, iaurt grecesc, lapte, gheață
# -------------------------------------------------------------------------------------------
# Tropical Medium 400 ml      14
# Ananas,mango, papaya,suc de mere,gheață
# -------------------------------------------------------------------------------------------
# Green Fever Medium 400 ml      14
# Ananas,mango,avocado,banana,dovleac,busuioc,gheață
# -------------------------------------------------------------------------------------------
# Strawberry&Coconut Grande 500ml      14
# Lapte, piure de căpșuni, piure de cocos, frișcă
# -------------------------------------------------------------------------------------------
# Oreo Shake Grande 500 ml      14
# Biscuiți Oreo, sirop de ciocolată albă, lapte, gheață, frișcă
# -------------------------------------------------------------------------------------------
# Orange Grande 400 ml      16
#
# -------------------------------------------------------------------------------------------
# Grapefruit Grande 400 ml      16
#
# -------------------------------------------------------------------------------------------
# Classic Lemonade 500 ml      12
# Suc de lămâie, sirop de zahăr, apă, gheață
# -------------------------------------------------------------------------------------------
# Mint Lemonade 500 ml      12
# Suc de lămâie, sirop de zahăr, mentă, apă, gheață
# -------------------------------------------------------------------------------------------
# Elderflower&Mint Lemonade 500 ml      12
# Suc de lămâie, sirop de soc, sirop de zahăr, mentă, apă, gheață
# -------------------------------------------------------------------------------------------
# Melone Lemonade 500 ml      12
# Suc de lămâie, piure de pepene, sirop de zahăr, apă, gheață
# -------------------------------------------------------------------------------------------
# Strawberry&Peach Lemonade 500 ml      12
# Suc de lămâie, piure de căpșuni, piure de piersici, sirop de zahăr, apă, gheață
# -------------------------------------------------------------------------------------------
# Minty Ice Tea Grande 500 ml      12
# Ceai Nana Mint, miere, suc de lămâie, mentă, gheață
# -------------------------------------------------------------------------------------------
# Forestberry Grande 500 ml      12
# Ceai de fructe de pădure, miere, suc de lămâie, gheață
# -------------------------------------------------------------------------------------------
# Orange Ice Tea Grande 500 ml      12
# Ceai de portocale, miere, suc de lămâie, gheață
# -------------------------------------------------------------------------------------------
# Coca Cola 500 ml      9
#
# -------------------------------------------------------------------------------------------
# Coca Cola Zero 500 ml      9
#
# -------------------------------------------------------------------------------------------
# Dorna Apa Minerala 500 ml      8
#
# -------------------------------------------------------------------------------------------
# Dorna Izvorul Alb 500 ml      8
#
# -------------------------------------------------------------------------------------------
# Fanta Mango Zero 500 ml      9
#
# https://eeatingh.ro/targu-mures/piadina.html
# La Piadina
# -------------------------------------------------------------------------------------------
# Genova 310 g      26
# blat alb / integral 160 g, salam milano 50 g, brie 50 g, roșii 50 g
# -------------------------------------------------------------------------------------------
# Bari 310 g      26
# blat alb / blat integral 160 g, șuncă de porc 50 g, mozzarella 50 g, roșii 50 g
# -------------------------------------------------------------------------------------------
# Prosciutto Crudo 50 g      7
#
# -------------------------------------------------------------------------------------------
# Venezia 290 g      26
# blat alb / blat integral 160 g, prosciutto crudo afumat sau uscat 50 g, brânză cu mucegai 50 g, rucola 30 g
# -------------------------------------------------------------------------------------------
# Pui 100 g      7
# PIept de pui 100 g
# -------------------------------------------------------------------------------------------
# Verona 290 g      26
# blat alb / blat integral 160 g, prosciutto crudo afumat sau uscat 50 g, brie 50 g, rucola 30 g
# -------------------------------------------------------------------------------------------
# Salam Milano 50 g      7
# Salam Milano 50 g
# -------------------------------------------------------------------------------------------
# Rimini 290 g      26
# blat alb / blat integral 160 g, prosciutto crudo afumat sau uscat 50 g, mozzarella 50 g, rucola 30 g
# -------------------------------------------------------------------------------------------
# Sunca Porc 50 g      7
# Sunca Porc  Praga 50 g
# -------------------------------------------------------------------------------------------
# Pisa 290 g      26
# blat alb / blat integral 160 g, prosciutto crudo afumat sau uscat 50 g, cremă de brânză 50 g, rucola 30 g
# -------------------------------------------------------------------------------------------
# Salam Chorizo 50 g      7
# Salam Chorizo 50 g
# -------------------------------------------------------------------------------------------
# Milano 310 g      26
# blat alb / integral 160 g, salam milano 50 g, cremă de brânză 50 g, roșii 50 g
# -------------------------------------------------------------------------------------------
# Sunca Pui 50 g      7
# Sunca Pui 50 g
# -------------------------------------------------------------------------------------------
# Padova 340 gr      28
# (blat alb/ blat integral 160 g, salam chorizo 50 g, mozzarella 50 g, ciuperci 50 g, rucola 30 g
# -------------------------------------------------------------------------------------------
# Ton 50 g      7
# Ton 50 g
# -------------------------------------------------------------------------------------------
# Al Tonno 320 gr      26
# blat alb/ blat integral 160 g, ton 50 g, roşii 50 g, rucola 30 g, porumb 30 g
# -------------------------------------------------------------------------------------------
# Mortadella 50 g      7
# mortadella 50 g
# -------------------------------------------------------------------------------------------
# Chicken 340g      26
# blat alb/ blat integral 160 g, piept de pui 100 g, cremă de brânză 50 g, rucola 30 g
# -------------------------------------------------------------------------------------------
# Salam Napoli 50 g      7
# Salam Napoli 50 g
# -------------------------------------------------------------------------------------------
# Vegetariana 360 gr      30
# blat alb/ blat integral 160 g, dovlecei la grătar 40 g, mozzarella 50 g, ciuperci 50 g, porumb 30 g, rucola 30 g
# -------------------------------------------------------------------------------------------
# Brie 50 g      7
# Brie 50 g
# -------------------------------------------------------------------------------------------
# 4 Formaggi 360 gr      34
# blat alb/ blat integral 160 g, brânză cu mucegai 50 g, brânză maturată Gran Regale 50 g, brie 50 g, mozzarella 50 g
# -------------------------------------------------------------------------------------------
# Crema de Branza 50 g      7
# Crema de branza 50 g
# -------------------------------------------------------------------------------------------
# Jungle Piadina 390 gr      27
# blat alb / integral 160 g, brânză Cheddar 80 g, salam Chorizo 50 g, castraveți murați 50 g, salată iceberg 50 g.
# -------------------------------------------------------------------------------------------
# Danish White 50 g      7
# Danish White 50 g
# -------------------------------------------------------------------------------------------
# Napoli Piadina 360 g      29
# blat alb/ integral 160 g, brie 50 g, salam Napoli 50 g, sos mustar frantuzesc 50 g, iceberg 50 g
# -------------------------------------------------------------------------------------------
# Branza cu mucegai 50 g      7
# Branza cu mucegai 50 g
# -------------------------------------------------------------------------------------------
# Hot Capere Piadina 325 g      29
# Blat alb/integral 160 g, ton 50 g, ardei iute jalapeno 25 g, branza Cheddar 50 g, sos cheddar 30 g, capere 10 g
# -------------------------------------------------------------------------------------------
# Mozzarella 50 g      7
# Mozzarella 50 g
# -------------------------------------------------------------------------------------------
# Mortadella 360 g      30
# Blat alb/ integral 160 g, mortadella cu fistic 70 g, mozzarella 50 g, maioneza 50 g, castraveti murati 30 g.
# -------------------------------------------------------------------------------------------
# Branza maturata Gran Regale 20g      7
# Branza maturata Gran Regale 50 g
# -------------------------------------------------------------------------------------------
# Tutun Piadina 360 gr      28
# blat alb/ integral 160 g, crema ardei copti 50 g, danish white 50 g, bacon 50 g,  rosii 40 g, ceapa prajita.
# -------------------------------------------------------------------------------------------
# Cheddar 50 g      7
# Cheddar 50 g
# -------------------------------------------------------------------------------------------
# Pizza Margherita 480 g      32
# Blat pizza (300 g), sos de roșii (50 g), mozzarella (130 g)
# -------------------------------------------------------------------------------------------
# Pizza Prosciutto 550 g      35
# Blat pizza (300 g), sos de roșii (50 g), mozzarella (130 g), sunca de porc (70g)
# -------------------------------------------------------------------------------------------
# Pizza Prosciutto e Funghi 510 g      36
# Blat pizza (300 g), sos de roșii (50 g), mozzarella (100 g), sunca de porc (70 g), ciuperci (40 g)
# -------------------------------------------------------------------------------------------
# Pizza Diavolo 550 g      36
# Blat pizza (300 g), sos roșii (50 g), mozzarella (100 g), salam picant chorizo (70 g), ceapă (30 g), usturoi
# -------------------------------------------------------------------------------------------
# Pizza Hot Chorizo 540 g      35
# Blat pizza (300 g), sos roșii (50 g), mozzarella (100 g), salam chorizo (70 g), ardei jalapeno (20 g)
# -------------------------------------------------------------------------------------------
# Pizza Quatro Carni 570 g      38
# Blat pizza (300 g), sos roșii (50 g), mozzarella (100 g), sunca de porc (30 g), salam (30 g), bacon (30 g), piept de pui (30 g)
# -------------------------------------------------------------------------------------------
# Pizza Dr.Chicken 570 g      35
# Blat pizza (300 g), smântână (50 g), mozzarella (100 g), piept de pui (100 g) , praz 20 g, usturoi
# -------------------------------------------------------------------------------------------
# Pizza Capricciosa 590 g      38
# Blat pizza (300 g), sos de roșii (50 g), șuncă (60 g), mozzarella (100 g), ciuperci (40 g), anghinare (20 g), măsline (20 g)
# -------------------------------------------------------------------------------------------
# Pizza Prosciutto e Rucola 540 g      38
# Blat de pizza (300 g), sos de roșii (50 g), mozzarella (100 g), parmezan (20 g), prosciuto crudo (50 g), rucola (20 g)
# -------------------------------------------------------------------------------------------
# Minis Beef Burger 400 g      39
# carne de vită 130 g, cartofi prăjiți 100 g, chiflă 60 g, salată iceberg 20 g, roșii 20 g, castraveți murați 20 g, sos Mini 20 g, cașcaval Cheddar 20 g, bacon
# -------------------------------------------------------------------------------------------
# Minis Crispy Chicken Burger 375 g      37
# crispy de pui 100 g, cartofi prăjiți 100 g, chiflă burger 60 g, salată iceberg 20 g, roșii 20 g, castraveți murați 20 g, sos Mini 20 g, cașcaval Cheddar 20 g, bacon
# -------------------------------------------------------------------------------------------
# Liguria Salad 370 gr      30
# Piept de pui (100 g), Danish White (50 g), ceapă roșie (30 g), porumb (30 g), roșii (50 g), rucola (30 g), blat Piadina (80 g).
# -------------------------------------------------------------------------------------------
# Romagna Salad 380 gr      30
# Piept de pui (100 g), branza cu mucegai (50 g), salată iceberg (50 g), ciperci crude (50 g), roșii (50 g), blat Piadina (80 g).
# -------------------------------------------------------------------------------------------
# Piemonte Salad 390 gr      27
# Piept de pui (100 g), roșii (50 g), morcovi (50 g), ciuperci crude (50 g), ceapă roșie (30 g), rucola (30 g), blat Piadina (80 g).
# -------------------------------------------------------------------------------------------
# Puglia Salad 370 gr      26
# Danish White (50 g), morcovi (50 g), țelină Apio (50 g), salată iceberg (50 g), roșii (50 g), dovlecel la grătar (40 g), blat Piadina (80 g).
# -------------------------------------------------------------------------------------------
# Sicilia Salad 370 gr      29
# Ton (50 g), țelină Apio (50 g), roșii (50 g), salată iceberg (50 g), rucola (30 g), măsline (30 g), ceapă roșie (30 g), blat Piadina (80 g)
# -------------------------------------------------------------------------------------------
# Veneto Salad 380 gr      30
# Brânză cu mucegai 50 g), roșii (50 g), morcovi (50 g), dovlecel la grătar (40 g), ciuperci crude (50 g), rucola (30 g), semințe de floarea soarelui (30 g), blat Piadina (80 g).
# -------------------------------------------------------------------------------------------
# Sardegna Salad 360 g      29
# Ton (50 g), morcovi (50 g), țelină Apio (50 g), porumb dulce (30 g), roșii (50 g), salată iceberg (50 g), blat Piadina (80 g)
# -------------------------------------------------------------------------------------------
# Caesar Salad 390 gr      32
# Piept de pui (100 g), salată iceberg (50 g), roșii (50 g), castraveți (50 g), sos Caesar (30g), brânză maturată Gran Regale (30 g), blat Piadina (80 g)
# -------------------------------------------------------------------------------------------
# Garlic Carbonara 400 g      31
# Spaghetti (200 g), bacon (70 g), cremă de gătit (150 ml), usturoi, parmezan (30 g).
# -------------------------------------------------------------------------------------------
# Sos Usturoi 30 gr      3
# 30 gr
# -------------------------------------------------------------------------------------------
# Ambalaj      3
#
# -------------------------------------------------------------------------------------------
# Coca Cola 500 ml      8
#
# -------------------------------------------------------------------------------------------
# Coca Cola Zero 500 ml      8
#
# -------------------------------------------------------------------------------------------
# Fanta Madness 500 ml      8
#
# -------------------------------------------------------------------------------------------
# Fanta Orange 500 ml      8
#
# -------------------------------------------------------------------------------------------
# Izvorul Alb Dorna 500 ml      7
#
# -------------------------------------------------------------------------------------------
# Apa minerala Dorna 500 ml      7
#
# -------------------------------------------------------------------------------------------
# Schweppes Bitterlemon 500 ml      8
#
# -------------------------------------------------------------------------------------------
# Schweppes Tonic 500ML      8
#
# -------------------------------------------------------------------------------------------
# Sprite 500 ml      8
#
# -------------------------------------------------------------------------------------------
# Schweppes Pink Tonic 500 ml      8
# Schweppes Pink Tonic 500 ml
# https://eeatingh.ro/targu-mures/2sticks.html
# 2Stix
# -------------------------------------------------------------------------------------------
# Coaste de Porc 300/200/100 g      42
# Coaste de porc, cartofi aurii, sos de hrean, varză murată / sertésborda, aranykrumpli, tormaszósz, savanyú káposzta - 300/200/100g
# -------------------------------------------------------------------------------------------
# Piedone's Plate 500 g      33
# cartofi aurii, cârnați cu cașcaval, sare, piper, boia de ardei, fasole, ceapă galbenă, varză murată arany krumpli, sajtos kolbász, só, bors, piros paprika, bab, sárga hagyma, savanyú káposzta - 10 - 350 / 150 g
# -------------------------------------------------------------------------------------------
# Baked Sausage Sandwich 500 g      27
# Aluat langoș, cârnați cu cașcaval, mozzarella, brânză feliată, salată iceberg, cartofi pai 250 g/ 100 g
# -------------------------------------------------------------------------------------------
# Rulouri cu Salam Picant 300 g      24
#
# -------------------------------------------------------------------------------------------
# Rulouri cu Sunca 300 g      24
#
# -------------------------------------------------------------------------------------------
# Meniu Galfalvi 200/160/100 g      33
#
# -------------------------------------------------------------------------------------------
# Schnitzel "G" 270 / 180 g      33
# Cotlet de porc in pesmet 270 g, cartofi 120 g, ardei kapia 30 g, ceapa rosie 30 g
# -------------------------------------------------------------------------------------------
# Hungarian Spicy 50 g      5
#
# -------------------------------------------------------------------------------------------
# Sos de Hrean 50 g      5
#
# -------------------------------------------------------------------------------------------
# Sos de Usturoi 50 g      5
#
# -------------------------------------------------------------------------------------------
# Mustar Dulce 50 g      4
#
# -------------------------------------------------------------------------------------------
# Mustar Picant 50 g      4
#
# -------------------------------------------------------------------------------------------
# Ketchup Dulce 50 g      4
#
# -------------------------------------------------------------------------------------------
# Ketchup Picant 50 g      4
#
# -------------------------------------------------------------------------------------------
# Coca Cola 500 ml      10
#
# -------------------------------------------------------------------------------------------
# Coca Cola Zero 500 ml      10
#
# -------------------------------------------------------------------------------------------
# Dorna Apa Minerala 500 ml      75
#
# -------------------------------------------------------------------------------------------
# Dorna Izvorul Alb 500 ml      75
#
# -------------------------------------------------------------------------------------------
# Fanta Portocale 500 ml      10
#
# -------------------------------------------------------------------------------------------
# Clatite cu Caise 250 g      15
#
# -------------------------------------------------------------------------------------------
# Clatite cu Ciocolata 250 g      15
#
# -------------------------------------------------------------------------------------------
# Gulas Sausage Soup 350 g      18
#
# https://eeatingh.ro/targu-mures/shusha-good-food-for-you.html
# Shusha - Good Food For You
# -------------------------------------------------------------------------------------------
# Burger Clasic      24
# Chiflă, 100% vită proaspătă, sos de casă, salată, roșii, ceapă caramelizată, brânză topită
# -------------------------------------------------------------------------------------------
# Burger Country      25
# Chiflă, 100% vită proaspătă, sos de casă cu bacon afumat, salată, roșii, ceapă caramelizată, brânză topită
# -------------------------------------------------------------------------------------------
# New Yorker      215
# Chiflă, piept de pui pane, sos Ranch de casă, salată, roșii
# -------------------------------------------------------------------------------------------
# Broadway Sub      22
# Chiflă, piept de pui pane, sos de casă, salată, măsline verzi, roșii uscate și marinate în ulei
# -------------------------------------------------------------------------------------------
# Melanzane      21
# Chiflă, vinete pane, sos Marinara de casă, salată, ardei, brânză topită
# -------------------------------------------------------------------------------------------
# American Hot Dog      14
# Chiflă, cârnăcior, castravete murat, ceapă verde, ketchup, muștar, maioneză
# -------------------------------------------------------------------------------------------
# Shawarma      24
# Lipie, piept de pui marinat, cartofi prăjiți, varză albă, roșii, castraveți, ceapă verde, condimente, sos Tzatziki de casă, condimente
# -------------------------------------------------------------------------------------------
# Wrap Clasic / Country      25
# Lipie, piept de pui marinat, cartofi prăjiți, salată iceberg, roșii, ceapă caramelizată, brânză topită, sos de casă (la alegere clasic sau country)
# -------------------------------------------------------------------------------------------
# Mexican Taco      20
# Lipie Tortilla, carne amestec vită cu porc, salată iceberg, roșii, ceapă verde, brânză topită, smântână, sos Salsa de casă
# -------------------------------------------------------------------------------------------
# Louisiana Cup      13
# Supă in stil New Orleans cu piept de pui marinat, cârnăcior, vegetale proaspete, condimente
# -------------------------------------------------------------------------------------------
# Nachos Bell Grande      295
# Tortilla chips, carne amestec vită cu porc, roșii, ceapă verde, brânză topită, smântână, sos Salsa de casă
# -------------------------------------------------------------------------------------------
# Ranch Salad      265
# Salată iceberg, piept de pui marinat, varză roșie, sos Ranch de casă
# -------------------------------------------------------------------------------------------
# Tiffany Salad      285
# Salată iceberg, piept de pui marinat, măsline verzi, roșii uscate și marinate în ulei, sos de casă
# -------------------------------------------------------------------------------------------
# Chin Chin Salad      285
# Salată iceberg, orez, piept de pui marinat, varză roșie, semințe, sos de casă dulce-acrișor cu ananas
# -------------------------------------------------------------------------------------------
# Ranger's Menu      26
# Piept de pui crocant, cartofi prăjiți, condimente
# -------------------------------------------------------------------------------------------
# Sheriff's Menu      30
# Piept de pui crocant, cartofi prăjiți, salată Ranch, condimente
# -------------------------------------------------------------------------------------------
# Teriyaki      30
# Orez, legume și condimente asiatice, piept de pui marinat, sos de casă dulce-acrișor cu ananas
# -------------------------------------------------------------------------------------------
# Malibu Cream      30
# Penne, ton, usturoi, sos alb de casă cu gorgonzola, condimente, parmezan
# -------------------------------------------------------------------------------------------
# Bolognese450 gr      30
# Spaghetti, carne amestec vită cu porc, sos de roșii, condimente, parmesan cheese
# -------------------------------------------------------------------------------------------
# Tomatillo      30
# Fusilli, cârnăcior puțin picant, sos Marinara de casă cu trei tipuri de ardei și ciuperci, condimente, parmesan cheese
# -------------------------------------------------------------------------------------------
# Pad Thai      35
# Tăiței de orez, piept de pui marinat, sos de alune condimentat thailandez, bamboo, fasole verde, muguri de fasole, omletă, sos de casă dulce-acrișor cu ananas
# -------------------------------------------------------------------------------------------
# Cheesy Crêpes      12
# Făină, ou, lapte, brânză
# -------------------------------------------------------------------------------------------
# Clătite Black Forest      12
# Făină, ou, lapte; sos de ciocolată, dulceață de fructe, zahăr pudră
# -------------------------------------------------------------------------------------------
# Farmer’s Daily      29
# Supă & Sandwich la alegere dintre: New Yorker, Broadway, Melanzane
# -------------------------------------------------------------------------------------------
# COMBO      35
# Supă & orice produs de pe meniu (în afară de New Yorker, Broadway, Melanzane, Pad Thai)
# -------------------------------------------------------------------------------------------
# Cartofi Prăjiți      6
# Cartofi prăjiţi condimentaţi cu verdeţuri; opţional sosuri: ketchup, maioneză, Ranch, Clasic
# -------------------------------------------------------------------------------------------
# Sos Ketchup      2
# Sos ketchup
# -------------------------------------------------------------------------------------------
# Sos Ranch      3
# Sos de casă pe bază de iaurt, condimente și usturoi
# -------------------------------------------------------------------------------------------
# Sos Maioneză      2
# Sos maioneză
# -------------------------------------------------------------------------------------------
# Sos Clasic      3
# Sos de casă Thousand Island
# -------------------------------------------------------------------------------------------
# Coca Cola 500 ml      8
# Coca Cola 500 ml
# -------------------------------------------------------------------------------------------
# Coca Cola 330 ml      7
# Coca Cola 330 ml
# -------------------------------------------------------------------------------------------
# Coca Cola Zero 330 ml      7
# Coca Cola Zero 330 ml
# -------------------------------------------------------------------------------------------
# Coca Cola 250 ml      65
# Coca Cola 250 ml
# -------------------------------------------------------------------------------------------
# Fanta Portocale 500 ml      8
# Fanta Portocale 500 ml
# -------------------------------------------------------------------------------------------
# Fuzetea Lămâie 500 ml      85
# Fuzetea Lămâie 500 ml
# -------------------------------------------------------------------------------------------
# Fuzetea Piersici 500 ml      85
# Fuzetea Piersici 500 ml
# -------------------------------------------------------------------------------------------
# Schweppes Apă Tonică 500 ml      85
# Schweppes Apă Tonică 500 ml
# -------------------------------------------------------------------------------------------
# Cappy Portocale 330 ml      8
# Cappy Portocale 330 ml
# -------------------------------------------------------------------------------------------
# Dorna Apă Plată 500 ml      6
# Dorna Apă Plată 500 ml
# -------------------------------------------------------------------------------------------
# Dorna Apă Minerală 500 ml      6
# Dorna Apă Minerală 500 ml
# https://eeatingh.ro/targu-mures/cube-ramen-sushi.html
# Cube Ramen & Sushi
# -------------------------------------------------------------------------------------------
# Shoyu Ramen Chicken 500 g      38
# Carne la alegere, bază Shoyu ramen, soia, ghimbir, usturoi, ulei de peste, paste ramen, ou fiert, edamame, ciuperci Shitake, ceapă verde, alge - 500 g
# -------------------------------------------------------------------------------------------
# Shoyu Ramen Pork 500 g      41
# Carne de porc, bază Shoyu ramen, soia, ghimbir, usturoi, ulei de peste, paste ramen, ou fiert, edamame, ciuperci Shitake, ceapă verde, alge - 500 g
# -------------------------------------------------------------------------------------------
# Shoyu Ramen Shrimp 500 g      45
# Creveti, bază Shoyu ramen, soia, ghimbir, usturoi, ulei de peste, paste ramen, ou fiert, edamame, ciuperci Shitake, ceapă verde, alge - 500 g
# -------------------------------------------------------------------------------------------
# Spicy Tom Yum Ramen Chicken 500 g      38
# Pui, bază Tom Yum ramen, paste ramen, ou fiert, edamame, ciuperci Shitake, ceapă verde, lime, alge
# -------------------------------------------------------------------------------------------
# Spicy Tom Yum Ramen Pork 500 g      41
# Carne porc, bază Tom Yum ramen, paste ramen, ou fiert, edamame, ciuperci Shitake, ceapă verde, lime, alge
# -------------------------------------------------------------------------------------------
# Spicy Tom Yum Ramen Shrimp 500 g      45
# Creveti, bază Tom Yum ramen, paste ramen, ou fiert, edamame, ciuperci Shitake, ceapă verde, lime, alge
# -------------------------------------------------------------------------------------------
# Salmon Big Rolls 275 g      35
# foi alge, orez sushi, somon, castraveți, avocado, sos de soia, wasabi, ghimbir murat - 230/30/5/10 g
# -------------------------------------------------------------------------------------------
# Special Deep Fried Rolls 275 g      39
# foi alge, orez sushi, somon , castraveti,cremă de brânză Philadelphia, ou, crustă crocantă, sos de soia, wasabi, ghimbir murat - 230/30/5/10 g
# -------------------------------------------------------------------------------------------
# Tuna Big Rolls 275 g      35
# foi alge, orez sushi, ton, avocado, ridiche murată, sos de soia, wasabi, ghimbir murat - 230/30/5/10 g
# -------------------------------------------------------------------------------------------
# Veggie Rolls 275 g      30
# Orez sushi 150 g, ridichie murată 30 g, avocado 30 g, sos soia 30 g, morcovi 20 g, wasabi, ghimbir murat, foi alge
# -------------------------------------------------------------------------------------------
# Smoked Salmon Big Rolls 275 g      36
# foi alge, orez sushi, somon afumat, sos de soia, wasabi, ghimbir murat - 100/30/5/10 g
# -------------------------------------------------------------------------------------------
# Philadelphia Uramaki Rolls 245 g      38
# foi alge, orez sushi, somon, castraveți, cremă de brânză Philadelphia, icre Tobiko, sos de soia, wasabi, ghimbir murat - 200/30/5/10 g
# -------------------------------------------------------------------------------------------
# Avocado Rolls 195 g      24
# foi alge, orez sushi, avocado, sos de soia, wasabi, ghimbir murat - 100/30/5/10 g
# -------------------------------------------------------------------------------------------
# Smoked Salmon Rolls 195 g      28
# foi alge, orez sushi, somon afumat, sos de soia, wasabi, ghimbir murat - 100/30/5/10 g
# -------------------------------------------------------------------------------------------
# Salmon Rolls 195 g      28
#
# -------------------------------------------------------------------------------------------
# Tuna Rolls 195 g      28
# foi alge, orez sushi, ton, sos de soia, wasabi, ghimbir murat  100/30/5/10 g
# -------------------------------------------------------------------------------------------
# Ghimbir Murat 10 g      2
#
# -------------------------------------------------------------------------------------------
# Wasabi 10 g      2
#
# -------------------------------------------------------------------------------------------
# Sos Maioneza Japoneza 50 g      5
#
# -------------------------------------------------------------------------------------------
# Sos Shriracha Mayo 50 g      5
#
# -------------------------------------------------------------------------------------------
# Sos Soia 30 g      3
#
# -------------------------------------------------------------------------------------------
# Sos Sweet Chilli 50 g      6
#
# -------------------------------------------------------------------------------------------
# Hosomaki Mix 32 Buc 750 g      99
# Avocado Rolls 8, Salmon Rolls 8, Smoked Salmon Rolls 8, Tuna Rolls 8, sos soia, wasabi, ghimbir murat 620 / 90 / 15 / 30 g
# -------------------------------------------------------------------------------------------
# Salmon Combo 24 Buc 655 g      94
# Philadelphia Uramaki Rolls 8, Salmon Big Rolls 8, Salmon Rolls 8 sos soia, wasabi, ghimbir murat
# -------------------------------------------------------------------------------------------
# Fish Mix 610 g      78
# Salmon Rolls 8, Smoked Salmon Rolls 8, Tuna Rolls 8, sos soia, wasabi, ghimbir murat 480 / 90 / 15 g
# -------------------------------------------------------------------------------------------
# Chicken Poke 350 g      38
# bază de orez 100g, piept de pui 80g, ardei 20g, edamame 20g, morcovi 20g, alge Wakame, seminte de susan, sos Poke 60g
# -------------------------------------------------------------------------------------------
# Salmon&Gamberetti Poke 300 g      45
# bază de orez, somon, avocado, castraveți, morcovi, edamame, alge Wakame, semințe de susan, sos poke
# -------------------------------------------------------------------------------------------
# Asahi 330 ml      16
#
# -------------------------------------------------------------------------------------------
# Coca Cola 0.5 l      9
#
# -------------------------------------------------------------------------------------------
# Fanta Orange 0,5 l      9
#
# -------------------------------------------------------------------------------------------
# Dorna 0,5 l      7
#
# -------------------------------------------------------------------------------------------
# Izvorul Alb 0,5 l      7
#
# -------------------------------------------------------------------------------------------
# Cappuccino 300 ml      13
# Lapte 250 ml, espresso 30 ml, cremă de lapte
# https://eeatingh.ro/targu-mures/crispyland.html
# Crispyland
# -------------------------------------------------------------------------------------------
# Crispy Box 350 g      40
# Fășii din piept de pui crispy, 1 sos la alegere  350 g
# -------------------------------------------------------------------------------------------
# Mix Box 400 g      40
# Fâșii din piept de pui în crustă crocantă, aripi de pui în crustă crocantă, 1 sos la alegere 400 g
# -------------------------------------------------------------------------------------------
# Spicy Wings Box 400 g      40
# Aripi de pui picante în crustă crocantă, 1 sos la alegere 400 g
# -------------------------------------------------------------------------------------------
# Meniu Blue Cheese Strips 350 g      31
# Fâșii din piept de pui în crustă crocantă, blue cheese, cartofi prăjiți, 1 sos la alegere 200g/150g
# -------------------------------------------------------------------------------------------
# Meniu Crispy Strips 350 g      29
# Fâșii din piept de pui în crustă crocantă, cartofi prăjiți, 1 sos la alegere 200g/150g
# -------------------------------------------------------------------------------------------
# Meniu Parmezan and Herbs Strips 350 g      31
# Fâșii din piept de pui în crustă crocantă, parmezan, cartofi prăjiți, 1 sos la alegere 200g/150g
# -------------------------------------------------------------------------------------------
# Meniu Spicy Chicken 350 g      29
# Fâșii din piept de pui picant în crustă crocantă, cartofi prăjiți, 1 sos la alegere 200g/150g
# -------------------------------------------------------------------------------------------
# Meniu Spicy Wings 350 g      29
# Aripi de pui picante în crustă crocantă, cartofi prăjiți, 1 sos la alegere 200g/150g
# -------------------------------------------------------------------------------------------
# Crispy Maxi Box 1050 g      62
# Fâșii din piept de pui în crustă crocantă, cartofi prăjiți, 2 sosuri la alegere 750g/300g
# -------------------------------------------------------------------------------------------
# Mix Maxi Box 1000 g      62
# Fâșii din piept de pui în crustă crocantă, aripi de pui în crustă crocantă,cartofi prăjiți, 2 sosuri la alegere 700g/300g
# -------------------------------------------------------------------------------------------
# Spicy Wings Maxi Box 1000 g      62
# Aripi de pui în crustă crocantă, cartofi prăjiți, 2 sosuri la alegere 700g/300 g
# -------------------------------------------------------------------------------------------
# Cartofi Prajiti 180 g      75
#
# -------------------------------------------------------------------------------------------
# Cartofi dulci 180 g      10
#
# -------------------------------------------------------------------------------------------
# Cartofi Wedges 180 g      95
#
# -------------------------------------------------------------------------------------------
# BBQ Sos 75g      0
#
# -------------------------------------------------------------------------------------------
# Shriracha Mayo 75g      55
#
# -------------------------------------------------------------------------------------------
# Americano 75g      55
# 75 g
# -------------------------------------------------------------------------------------------
# Sos Usturoi 75g      55
#
# -------------------------------------------------------------------------------------------
# Tomato Basil 75g      55
#
# -------------------------------------------------------------------------------------------
# Sos Maioneza 75 g      55
#
# -------------------------------------------------------------------------------------------
# Coca Cola 500 ml      85
#
# -------------------------------------------------------------------------------------------
# Dorna 500 ml      65
#
# -------------------------------------------------------------------------------------------
# Izvorul Alb 500 ml      65
#
# -------------------------------------------------------------------------------------------
# Peroni Doza 500 ml      11
#
# -------------------------------------------------------------------------------------------
# Sprite 500 ml      85
#
# -------------------------------------------------------------------------------------------
# Ursus Doza 500 ml      9
#
# -------------------------------------------------------------------------------------------
# Fanta Orange 500 ml      85
#
# -------------------------------------------------------------------------------------------
# Apple Pie with Vanilla Ice Cream 220 g      15
#
# -------------------------------------------------------------------------------------------
# Blueberry Cheesecake 220 g      15
#
# -------------------------------------------------------------------------------------------
# Sweet Chili Sauce 75g      55
#
# -------------------------------------------------------------------------------------------
# Sos Pizza Dulce 75g      55
#
# https://eeatingh.ro/targu-mures/quick-bites.html
# Quick Bites
# -------------------------------------------------------------------------------------------
# Pizza Margherita45 cm      85
# sos de rosii,mozzarella, oregano, busuioc
# -------------------------------------------------------------------------------------------
# Pizza Prosciutto45 cm      51
# sos de rosii, mozzarella,sunca
# -------------------------------------------------------------------------------------------
# Pizza Prosciutto e Funghi45 cm      53
# sos rosii, mozarella, sunca ,ciuperci
# -------------------------------------------------------------------------------------------
# Pizza formaggi45 cm      85
# sos de rosii, gorgonzola, parmezan, mozzarella
# -------------------------------------------------------------------------------------------
# Pizza  cabanos45 cm      85
# sos de rosii, cabanos, porumb, mozarella
# -------------------------------------------------------------------------------------------
# Pizza  hot dog45 cm      51
# sos de rosi, mozzarella, sunculita taraneasca, ceapa
# -------------------------------------------------------------------------------------------
# Pizza taraneasca45 cm      85
# sos de rosi, mozzarella, sunculita taraneasca, ceapa
# -------------------------------------------------------------------------------------------
# Pizza salami45 cm      85
# sos de rosii, salam crud uscat, chorizo picant, mozzarella, branza de burduf, ciuperci
# -------------------------------------------------------------------------------------------
# Pizza  Funghi45 cm      48
# sos de rosii, mozarella, ciuperci
# -------------------------------------------------------------------------------------------
# Pizza Vegetariana45 cm      65
# sos de rosii, ciuperci, porumb, masline, ardei, rosii, oregano, busuioc
# -------------------------------------------------------------------------------------------
# Pizza con Carne45 cm      85
# sos de rosii, mozzarella, salam, carnati, sunculita taraneasca, ardei gras, masline
# -------------------------------------------------------------------------------------------
# Pizza Rustica45 cm      85
# sos de rosii, mozzarella, sunca taraneasca, carnati, masline, ceapa
# -------------------------------------------------------------------------------------------
# Pizza Spicy45 cm      85
# sos de rosii, mozzarella, chorizo picant,jalapeno, fulgi de chilli
# -------------------------------------------------------------------------------------------
# Pizza Calzone      34
# sos de rosii, mozzarella, ciuperci, sunca, porumb
# -------------------------------------------------------------------------------------------
# Pizza Yummy45 cm      56
# sos de rosii, bacon, salam, porumb, masline, rosii
# -------------------------------------------------------------------------------------------
# Pizza Capriciosa45 cm      85
# sos de rosii, masline , ardei
# -------------------------------------------------------------------------------------------
# Pizza Quattro Stagioni45 cm      85
# sos de rosii, mozzarella, sunca, salam, ciuperci, masline
# -------------------------------------------------------------------------------------------
# Pizza pollo45 cm      85
# sos de rosii, mozzarella, pastrama din piept de pui, porumb, ciuperci
# -------------------------------------------------------------------------------------------
# Pizza Margherita45 cm      83
# sos de rosii,mozzarella, oregano, busuioc, crema de branza
# -------------------------------------------------------------------------------------------
# Pizza Prosciutto45 cm      93
# sos de rosii, mozzarella, sunca, crema de branza
# -------------------------------------------------------------------------------------------
# Pizza Prosciutto e Funghi45 cm      75
# sos rosii, mozarella, sunca ,ciuperci, crema de branza
# -------------------------------------------------------------------------------------------
# Pizza formaggi45 cm      103
# sos de rosii, gorgonzola, parmezan, mozzarella, crema de branza
# -------------------------------------------------------------------------------------------
# Pizza taraneasca45 cm      103
# sos de rosi, mozzarella, sunculita taraneasca, ceapa, crema de branza
# -------------------------------------------------------------------------------------------
# Pizza pollo45 cm      103
# sos de rosii, mozzarella, pastrama din piept de pui, porumb, ciuperci, crema de branza
# -------------------------------------------------------------------------------------------
# Pizza  Funghi45 cm      93
# sos de rosii, mozarella, ciuperci, crema de branza
# -------------------------------------------------------------------------------------------
# Pizza con Carne45 cm      103
# sos de rosii, mozzarella, salam, carnati, sunculita taraneasca, ardei gras, masline, crema de branza
# -------------------------------------------------------------------------------------------
# Pizza Spicy45 cm      103
# sos de rosii, mozzarella, chorizo picant,jalapeno, fulgi de chilli, crema de branza
# -------------------------------------------------------------------------------------------
# Pizza  cabanos45 cm      103
# sos de rosii, cabanos, porumb, mozarella, crema de branza
# -------------------------------------------------------------------------------------------
# Pizza  hot dog45 cm      65
# sos de rosi, mozzarella, sunculita taraneasca, ceapa, crema de branza
# -------------------------------------------------------------------------------------------
# Pizza salami45 cm      103
# sos de rosii, salam crud uscat, chorizo picant, mozzarella, branza de burduf, ciuperci, crema de branza
# -------------------------------------------------------------------------------------------
# Pizza Vegetariana cu mozzarella45 cm      83
# sos de rosii, ciuperci, porumb, masline, ardei, rosii, oregano, busuioc, crema de branza
# -------------------------------------------------------------------------------------------
# Pizza Rustica45 cm      103
# sos de rosii, mozzarella, sunca taraneasca, carnati, masline, ceapa, crema de branza
# -------------------------------------------------------------------------------------------
# Pizza Yummy45 cm      103
# sos de rosii, bacon, salam, porumb, masline, rosii, crema de branza
# -------------------------------------------------------------------------------------------
# Pizza Capriciosa45 cm      103
# sos de rosii, masline , ardei, crema de branza
# -------------------------------------------------------------------------------------------
# Pizza Quattro Stagioni45 cm      103
# sos de rosii, mozzarella, sunca, salam, ciuperci, masline, crema de branza
# -------------------------------------------------------------------------------------------
# Specialitate salam      25
# salam crud uscat, branza burduf, cascaval, ardei gras
# -------------------------------------------------------------------------------------------
# Specialitate sunca      25
# sunca, branza de burduf, cascaval, ardei gras
# -------------------------------------------------------------------------------------------
# Specialitate cu snitel de pui      28
# snitel de pui, branza de burduf, cascaval, castraveti murati
# ...
# Ingrediente: apă, malț de orz, hamei.<br />
# Conținut de alcool 5,10 %
# -------------------------------------------------------------------------------------------
# Dinkelacker Alkoholfrei (fara alcool) 0.33lStandard      555
# O bere fără alcool proaspătă, ușor picantă. O specialitate de bere elaborat preparată. Băută rece este un adevărat răsfăț pentru zilele toride de vară, dar nu numai.<br />
# Ingrediente: apă, malț de orz, hamei<br />
# Conținut de alcool 0,00 %
# -------------------------------------------------------------------------------------------
# Schwaben Bräu – Das SchwarzeStandard      1283
# Preparată conform legii purității germane, cu produse naturale atent selecționate care îndeplinesc cele mai înalte standarde de calitate. Este o bere Lager de culoare profund neagră cu un gust picant și totodată amar de hamei. Este o bere de fermentare joasă, specială pentru cunoscători și iubitorii de arome deosebite.<br />
# Ingrediente: apă, malț de orz, hamei, extract de hamei.<br />
# Conținut de alcool 4,9 %
# -------------------------------------------------------------------------------------------
# Dinkelacker Naturradler 0.33lStandard      649
# O bere clasică din 50 % bere proaspată Dinkelacker și 50 % bautură răcoritoare cu aromă de lămâie.<br />
# Ingrediente: apă, malț de orz, hamei, bere, zahăr, suc de lămâie,dioxid de carbon.<br />
# Conținut de alcool 2,50 %
# -------------------------------------------------------------------------------------------
# Barracuda Spiced RumStandard      16622
# Barracuda este un rom caribian condimentat cu chili.<br />
# Poți să-l bei ca shot, pe gheață sau amestecat cu cola sau bere de ghimbir.<br />
# Produs în Germania. – Conținut de alcool 35% – Prezentare în sticlă de 0,7l
# -------------------------------------------------------------------------------------------
# Lichior Ficken 0.7 lStandard      8311
# Lichiorul „FICKEN“ este o băutură alcoolică perfectă pentru petreceri. Se poate servi atât pur, precum și amestecat cu diferite sucuri de fructe sau băuturi răcoritoare.<br />
# Conținut de alcool: 15 %
# -------------------------------------------------------------------------------------------
# Vodka PrimakovStandard      4534
# Primakov Vodca este produs din cel mai bun grâu de toamnă. Limpede și clară, ideal pentru cocktails.<br />
# Produs în Germania.<br />
# Conținut de alcool 37,5%
# -------------------------------------------------------------------------------------------
# Berlacha Williams – Tuica de pereStandard      6951
# Produsă exclusiv din pere coapte în mod natural.<br />
# Produs în Germania – Conținut de alcool 40% – Prezentare în sticlă de 0,7l
# -------------------------------------------------------------------------------------------
# Lichior Ficken 3 lStandard      35499
# Lichiorul „FICKEN“ este o băutură alcoolică perfectă pentru petreceri. Se poate servi atât pur, precum și amestecat cu diferite sucuri de fructe sau băuturi răcoritoare.<br />
# Conținut de alcool: 15 %
# -------------------------------------------------------------------------------------------
# Earl Brown Dry GinStandard      4986
# Acest Gin tipic britanic produs din ienupăr, are un gust pronunțat de ienupăr, arome ușoare de citrice și un caracter uscat. De aceea acest Gin este perfect pentru un Gin tonic clasic sau multe alte cocktailuri și longdrinks.<br />
# Produs în Germania.<br />
# Conținut de alcool 37,5%
# -------------------------------------------------------------------------------------------
# Berlache Kernobstbrand- Tuica de fructeStandard      6798
# Produsă din diferite soiuri de mere și pere.<br />
# Produs în Germania – Conținut de alcool 37,5%
# -------------------------------------------------------------------------------------------
# Berlache Himbeer – Tuica de zmeuraStandard      5439
# Produsă din zmeură proaspătă și dulce.
# Produs în Germania – Conținut de alcool 40%
# -------------------------------------------------------------------------------------------
# Berlache Mirabelle – Tuica de corcoduseStandard      6951
# Produsă din prune galbene de cea mai bună calitate.<br />
# Produs în Germania – Conținut de alcool 40%
# -------------------------------------------------------------------------------------------
# Berlache Kirschbrand – Tuica de cireseStandard      9067
# Produsă din cele mai dulci cireșe negre, coapte în razele soarelui sudic.<br />
# Produs în Germania – Conținut de alcool 37,5%
# -------------------------------------------------------------------------------------------
# Pachet Bere blondă, Baisinger, Spezial, 6 sticle x 0,5l      5199
# Berea Baisinger Spezial este primul sortiment de bere produs de Familia Teufel.<br />
# Este produsă și astăzi dupa aceeași rețetă ca acum 235 de ani. Gustul ei autentic și plin de caracter este menținut și astăzi și de aceea se bucură de o mare popularitate printre cunoscatori. Mâncare recomandată: friptură picantă de vițel, tocaniță de pui, papanași.<br />
# Ingrediente: apă, malț de orz, hamei.<br />
# Conținut de alcool 5,2%
# -------------------------------------------------------------------------------------------
# Pachet Bere din grau bruna, Baisinger, Dunkles Hefeweizen, 6 sticle x 0.5 l      5199
# Sortimentul nostru de bere Baisinger Teufels Weisse Dunkles Hefeweizen aduce o experiență ieșită din comun în ceea ce privește berea. În acest sortiment se regasește prospețimea unei beri din grâu și gustul de nucă a malțului de grâu închis la culoare, toate acestea perfect armonizate una cu alta.<br />
# Ingrediente: apă, malț de grâu, malț de orz, drojdie, hamei, malț prăjit.
# -------------------------------------------------------------------------------------------
# Pachet Bere din grau filtrata, Baisinger, Kristallweizen, 6 sticle x 0,5l      5199
# Băutură răcoritoare delicioasă în felul lui Baisinger, obținută prin fermentație înaltă, pișcătoare și cu o aromă proaspată de grâu – acesta este sortimentul nostru de bere Baisinger Teufels Weisse Kristallweizen cu o densitate originală de 12%.<br />
# Ingrediente: apă, malț de grâu, malț de orz, hamei.<br />
# Conținut alcool: 5,2%.
# -------------------------------------------------------------------------------------------
# Pachet Bere din grau nefiltrata, Baisinger, Hefe Hell, 6 sticle x 0,5 l      5199
# Este o bere de fermentație înaltă, are o culoare galben solar și un gust cremos, cu note de fructe tropicale. Fermentația în sticlș face ca aceasta bere să fie intr-adevăr deosebită.<br />
# Ingrediente: apă, malț de grâu, malț de orz, drojdie. hamei.<br />
# Conținut de alcool: 5,2%
# -------------------------------------------------------------------------------------------
# Pachet Bere Pils, Baisinger, 6 sticle x 0,5l      5199
# Berea Baisinger Pils este un adevărat clasic printre sortimentele de bere. Aroma bogată de malț și nota proaspată de hamei se completează reciproc, ducând la un gust cu buchet.<br />
# Ingrediente: apă, malț de orz, hamei.<br />
# Conținut de alcool: 4.8%.
# -------------------------------------------------------------------------------------------
# Pachet bere blonda cu lamaie, Dinkelacker, Naturradler, 6 sticle x 0.33l      3799
# O bere clasică blondă din 50 % bere proaspătă Dinkelacker si 50 % băutură răcoritoare cu aromă de lămâie face din Dinkelacker Naturradler un tratament deosebit în zilele călduroase. Aromele proaspete de citrice, conferă acestei specialități spumoase caracterul său revigorant. O băutură ușoară de bere, care vara nu se adresează numai bicicliștilor, dar și tuturor celorlalți sportivi.<br />
# Ingrediente: apă, malț de orz, hamei, bere, zahăr, suc de lămâie,dioxid de carbon.<br />
# Conținut de alcool 2,50 %
# -------------------------------------------------------------------------------------------
# Pachet Bere din grau bruna, Sanwald, Weizen Dunkel, 6 sticle x 0.5l      5199
# Berea reprezinta recreerea, compania bună și distracția. Este o bere brună tulbure din grâu, preparată din malț de grâu brun.<br />
# O specialitate de bere din grâu pentru cunoscători.<br />
# Ingrediente: apă, malț de grâu, malț de orz, drojdie, hamei.<br />
# Conținut de alcool: 4.9%.
# -------------------------------------------------------------------------------------------
# Pachet Bere din grau filtrata, Sanwald, Kristall Weizen, 6 sticle x 0.5l      5199
# Această bere este denumită și coroana de grâu. Este o bere din grâu filtratș, luminoasș și cristalină.<br />
# Preparată din malț de grâu pal, hamei fin cu o aromă specială de drojdie.<br />
# Ingrediente: apă, malț de grâu, malț de orz, drojdie, hamei.<br />
# Conținut de alcool: 4.9%
# -------------------------------------------------------------------------------------------
# Pachet Bere din grau nefiltrata, Sanwald, Hefe Weizen, 6 sticle x 0.5l      5199
# Este o bere din grâu nefiltrată, pasteurizată, de culoare aurie, cu o spumă generoasă și persistentă.<br />
# Bere tradițională germană cu un miros plăcut de grâu și ușoare note de fructe.<br />
# Are un gust complex și echilibrat, o bere nefiltrată clasică.<br />
# Ingrediente: apă, malț de grâu, malț de orz, drojdie, hamei.<br />
# Conținut de alcool: 5%
# -------------------------------------------------------------------------------------------
# Pachet selectie beri, Dinkelacker, 6 x 500 mlStandard      5099
# Bere neagra Schwaben Brau Das Schwarze, 4,9% alcool.<br />
# Schwaben Brau Das KellerPils este o specialitate nefiltrata, tulbure care contine 5% alcool.<br />
# Dinkelacker Privat cu 5,3% alcool.<br />
# Sanwald Hefe Weizen cu 4,9% alcool.<br />
# Sanwald Dunkel Weizen cu 4,9% alcool.<br />
# Sanwald Kristall Weizen cu 5% alcool.
# https://eeatingh.ro/targu-mures/sprit-delivery.html
# Sprit Delivery
# -------------------------------------------------------------------------------------------
# Vinars (Divin/Cognac) Kvint 6 ani VSOP      79
# 0.7
# -------------------------------------------------------------------------------------------
# Vodca Voronskaya Platinum 40% 0.5l      34
#
# -------------------------------------------------------------------------------------------
# Vodca Voronskaya Classic 40% 0.2l      18
#
# -------------------------------------------------------------------------------------------
# Jagermesiter 1l      99
#
# -------------------------------------------------------------------------------------------
# Whiskey Famouse Grouse 0.7l      79
#
# -------------------------------------------------------------------------------------------
# Liliac Feteasca Regala      49
# Vin alb, sec
# -------------------------------------------------------------------------------------------
# Crama Santu - Gura de Rai - White Cuvee      39
# 13%, 0.75l
# -------------------------------------------------------------------------------------------
# Domeniul Bogdan Sauvignon Blanc Demisec      29
#
# -------------------------------------------------------------------------------------------
# Valea Ascunsa Muscat Ottonel Demidulce      34
# 0.75
# -------------------------------------------------------------------------------------------
# Spumant Cotnari Francusa      25
# Extrasec
# -------------------------------------------------------------------------------------------
# Liliac Rose      54
#
# -------------------------------------------------------------------------------------------
# Alira Rose 0.75 l      37
#
# -------------------------------------------------------------------------------------------
# Aurelia Visinescu Nomad Merlot      34
# Vin rosu
# -------------------------------------------------------------------------------------------
# Liliac Feteasca Neagra      65
# Vin rosu, sec
# -------------------------------------------------------------------------------------------
# Corona      7
# Bere Corona, 4%, 0.335
# -------------------------------------------------------------------------------------------
# Paulaner Weissbier      12
# Bere Paulaner Weiss, 0.5l
# -------------------------------------------------------------------------------------------
# Nenea Iancu Alba Nefiltrata      11
# Bere Alba Nefiltrata, 0.5l
# [Item(restaurant_name='Rexo LunchBox', url='https://eeatingh.ro/targu-mures/rexo-lunchbox.html', food_name='Cheesy Chicken Fries 330 g', description='cartofi pai 170 g, piept de pui 80 g, mozzarella 50 g, sos de usturoi, ceapă prâjită,', price='22'), Item(restaurant_name='Rexo LunchBox', url='https://eeatingh.ro/targu-mures/rexo-lunchbox.html', food_name='Quattro Stagioni Standard', description='blat pizza, sos pizza, mozzarella, șuncă, ciuperci, salam, porumb', price='30'), Item(restaurant_name='Rexo LunchBox', url='https://eeatingh.ro/targu-mures/rexo-lunchbox.html', food_name='Crispy Shaorma 400 g', description='crispy din piept de pui 120 g, lipie 60 g, salată 40 g, castraveți 40 g, roșii 30 g, ceapă 20 g, cartofi prăjiți 30 g, sos shaorma 40 g, sos de usturoi 25 g', price='236'), Item(restaurant_name='Rexo LunchBox', url='https://eeatingh.ro/targu-mures/rexo-lunchbox.html', food_name='Kung Pao Rice Box 400 g', description='carne la alegere, ceapă, ghimbir, usturoi, ardei chili, alune, sos dulce, sos de soia, orez Jasmine', price='284'), Item(restaurant_name='Rexo LunchBox', url='https://eeatingh.ro/targu-mures/rexo-lunchbox.html', food_name='Curry Ginger Noodle Box 400 g', description='piept de pui, ciuperci, morcovi, ceapă, ardei, roşii, ghimbir, chili, sos soia, paste noodle de casă', price='316'), Item(restaurant_name='Rexo LunchBox', url='https://eeatingh.ro/targu-mures/rexo-lunchbox.html', food_name='Shaorma de pui 350 g', description='piept de pui 80 g, lipie 60 g, salată 40 g, castraveți 40 g, roșii 30 g, ceapă 20 g, cartofi prăjiți 30 g, sos shaorma 40 g, sos de usturoi 25 g', price='275'), Item(restaurant_name='Rexo LunchBox', url='https://eeatingh.ro/targu-mures/rexo-lunchbox.html', food_name='Donner de pui 350 g', description='piept de pui 80 g, chiflă 80 g, salată 40 g, castraveți 40 g, roșii 30 g, ceapă 20 g, cartofi prăjiți 30 g, sos shaorma 40 g, sos de usturoi 25 g', price='275'), Item(restaurant_name='Rexo LunchBox', url='https://eeatingh.ro/targu-mures/rexo-lunchbox.html', food_name='Shaorma de pui la farfurie 480 g', description='piept de pui 120 g, lipie 100 g, salată 50 g, castraveți 50 g, roșii 40 g, ceapă 20 g, cartofi prăjiți 50 g, sos shaorma 40 g, sos de usturoi 30 g', price='315'), Item(restaurant_name='Rexo LunchBox', url='https://eeatingh.ro/targu-mures/rexo-lunchbox.html', food_name='Crispy Shaorma', description='crispy din piept de pui 120g, lipie 60g, salată 40g, castraveti 40g, rosii 30g, ceapa 20g, cartofi prăjiți 30g, sos shaorma 40g, sos usturoi 25g', price='295'), Item(restaurant_name='Rexo LunchBox', url='https://eeatingh.ro/targu-mures/rexo-lunchbox.html', food_name='Smashed Burger Fries 350 g', description='cartofi pai 170 g, carne de vită burger 80 g, brânză topită chedar 20 g, castraveți murați 30 g, sos burger, kechup, ceapă prâjită,', price='275'), Item(restaurant_name='Rexo LunchBox', url='https://eeatingh.ro/targu-mures/rexo-lunchbox.html', food_name='Bacon and Blue Cheese Fries 300 g', description='cartofi pai 170 g, kaiser 80 g, brânză cu mucegai 20 g, sos de ciuperci, ceapă prâjită,', price='275'), Item(restaurant_name='Rexo LunchBox', url='https://eeatingh.ro/targu-mures/rexo-lunchbox.html', food_name='Cheesy Chicken Fries 330 g', description='cartofi pai 170 g, piept de pui 80 g, mozzarella 50 g, sos de usturoi, ceapă prâjită,', price='275'), Item(restaurant_name='Rexo LunchBox', url='https://eeatingh.ro/targu-mures/rexo-lunchbox.html', food_name='Smokey Chicken Fries 330 g', description='cartofi pai 170 g, piept de pui 80 g, cașcaval afumat 30 g, sos bbq, sos de maioneză, ceapă prâjită,', price='275'), Item(restaurant_name='Rexo LunchBox', url='https://eeatingh.ro/targu-mures/rexo-lunchbox.html', food_name='Single Pack 400 g', description='piept de pui sau aripi de pui crispy, cartofi prăjiți, 1 sos la alegerecrispy csirkemell vagy csirkeszárny, sült burgonya, 1 választható szósz', price='275'), Item(restaurant_name='Rexo LunchBox', url='https://eeatingh.ro/targu-mures/r ...

# %% [markdown]
# 2. Éttermenként töltsük le a vendeglők adatlapját. Az étterem adatlapján megtalálható az adott vendéglő menüje. Haladjunk végig az összes éttermen, töltsük le őket, és keressük ki a rendelhető fogásokat. Mentsük le az ételek / italok nevét, árát és leírását, illetve az étterem nevét, ahol rendelni lehet őket. Ezeket az információkat mentsük ki egy DataFrame-be. Mentsük ki a DataFrame-et egy állományba, hogy később gyorsabban lehessen az adatokat feldolgozni!
#
# Segítség: Mindegyik rendelhető étel felfogható egy külön entitásként. A rendelhető ételek egy-egy div-nek felelnek meg a HTML forrásállományban. Használjuk a Chrome `Inspect Element` funkcionalitását, hogy találjuk meg azt az attribútumot, amivel ki lehet szűrni a rendelhető fogásokat. Az étel nevét és árát ugyancsak ki lehet szedni egy-egy HTML elemből.
#
# ![image.png](attachment:image.png)

# %%
new_path = '/content/drive/My Drive/Colab Notebooks/foodInfo.csv'
df2 = pd.read_csv(new_path)
df2
# Out:
#      restaurant_name                                                url  \
# 0      Rexo LunchBox  https://eeatingh.ro/targu-mures/rexo-lunchbox....
# 1      Rexo LunchBox  https://eeatingh.ro/targu-mures/rexo-lunchbox....
# 2      Rexo LunchBox  https://eeatingh.ro/targu-mures/rexo-lunchbox....
# 3      Rexo LunchBox  https://eeatingh.ro/targu-mures/rexo-lunchbox....
# 4      Rexo LunchBox  https://eeatingh.ro/targu-mures/rexo-lunchbox....
# ...              ...                                                ...
# 8239  Sprit Delivery  https://eeatingh.ro/targu-mures/sprit-delivery...
# 8240  Sprit Delivery  https://eeatingh.ro/targu-mures/sprit-delivery...
# 8241  Sprit Delivery  https://eeatingh.ro/targu-mures/sprit-delivery...
# 8242  Sprit Delivery  https://eeatingh.ro/targu-mures/sprit-delivery...
# 8243  Sprit Delivery  https://eeatingh.ro/targu-mures/sprit-delivery...
#
#                            food_name  \
# 0         Cheesy Chicken Fries 330 g
# 1          Quattro Stagioni Standard
# 2               Crispy Shaorma 400 g
# 3            Kung Pao Rice Box 400 g
# 4      Curry Ginger Noodle Box 400 g
# ...                              ...
# 8239  Aurelia Visinescu Nomad Merlot
# 8240          Liliac Feteasca Neagra
# 8241                          Corona
# 8242              Paulaner Weissbier
# 8243     Nenea Iancu Alba Nefiltrata
#
#                                             description  price
# 0     cartofi pai 170 g, piept de pui 80 g, mozzarel...     22
# 1     blat pizza, sos pizza, mozzarella, șuncă, ciup...     30
# 2     crispy din piept de pui 120 g, lipie 60 g, sal...    236
# 3     carne la alegere, ceapă, ghimbir, usturoi, ard...    284
# 4     piept de pui, ciuperci, morcovi, ceapă, ardei,...    316
# ...                                                 ...    ...
# 8239                                           Vin rosu     34
# 8240                                      Vin rosu, sec     65
# 8241                             Bere Corona, 4%, 0.335      7
# 8242                          Bere Paulaner Weiss, 0.5l     12
# 8243                         Bere Alba Nefiltrata, 0.5l     11
#
# [8244 rows x 5 columns]

# %% [markdown]
# 3. Keressük meg az összes olyan ételt, aminek a leírásában megtalálható a `pizza` szócska. Ezeket az ételeket rendezzük növekvő sorrendbe az áruk alapján. Másnéven: keressük meg Vásárhelyen a legolcsóbb és legdrágább pizzákat.

# %% [markdown]
# 4. Keressük meg az összes olyan ételt, ami 30 lej alatt megrendelhető.

# %% [markdown]
# 5. Melyik a legdrágább étel az oldalon?

# %% [markdown]
# 6. Melyik étteremnek van a legnagyobb kínálata?

# %% [markdown]
# 7. Számoljuk ki vendéglőnként az ételek átlag árát! Melyik étterem a legdrágább / legolcsóbb?
